# %%
import matplotlib.pyplot as plt
import numpy as np
# Utilize numpy to make uniform distribution
u = np.random.uniform(0,10,1000)
# Utilize matplotlib to generate and display uniform distribution 
plt.hist(u)
plt.show()
