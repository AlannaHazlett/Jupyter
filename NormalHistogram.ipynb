# %%
import matplotlib.pyplot as plt
import numpy as np
# generate random values that fit normal distribution with mean of 5 and standard deviation of 2 in a 2x4 array
s = np.random.normal(5, 2, size=(2, 4))
print(s)
# plot histogram of variable s utilizing matplotlib
plt.hist(s)
# display histogram 
plt.show()
# Out:
# [[ 5.83727789  3.97418268  2.27568588  6.42351952]
#  [ 6.14518684 10.41683808  3.48320264  4.5742579 ]]
